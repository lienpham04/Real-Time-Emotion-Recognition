# %%
pip install vaderSentiment nlpaug optuna emoji
# Out:
# Requirement already satisfied: vaderSentiment in /usr/local/lib/python3.12/dist-packages (3.3.2)
# Requirement already satisfied: nlpaug in /usr/local/lib/python3.12/dist-packages (1.1.11)
# Requirement already satisfied: optuna in /usr/local/lib/python3.12/dist-packages (4.6.0)
# Collecting emoji
#   Downloading emoji-2.15.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from vaderSentiment) (2.32.4)
# Requirement already satisfied: numpy>=1.16.2 in /usr/local/lib/python3.12/dist-packages (from nlpaug) (2.0.2)
# Requirement already satisfied: pandas>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from nlpaug) (2.2.2)
# Requirement already satisfied: gdown>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from nlpaug) (5.2.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (1.17.2)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.12/dist-packages (from optuna) (6.10.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.44)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.3)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from gdown>=4.0.0->nlpaug) (4.13.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from gdown>=4.0.0->nlpaug) (3.20.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2.0->nlpaug) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2.0->nlpaug) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2.0->nlpaug) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->vaderSentiment) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->vaderSentiment) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->vaderSentiment) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->vaderSentiment) (2025.11.12)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.2.0->nlpaug) (1.17.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown>=4.0.0->nlpaug) (2.8)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.3)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown>=4.0.0->nlpaug) (1.7.1)
# Downloading emoji-2.15.0-py3-none-any.whl (608 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 608.4/608.4 kB 20.0 MB/s eta 0:00:00
# Installing collected packages: emoji
# Successfully installed emoji-2.15.0

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 57.0 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
# ====== Full runnable Colab script (copy-paste into one cell) ======
# Installs (run once)
# !pip install -q transformers datasets torch scikit-learn pandas numpy tqdm optuna spacy vaderSentiment emoji nltk nlpaug
# !python -m spacy download en_core_web_sm

# -------------------------
# Imports & reproducibility
# -------------------------
import os, random, math, time
from collections import defaultdict
import numpy as np
import pandas as pd
import torch, torch.nn as nn
from torch.utils.data import Dataset, DataLoader, WeightedRandomSampler
from transformers import AutoTokenizer, AutoModel, AutoConfig, get_linear_schedule_with_warmup
from datasets import load_dataset
from sklearn.metrics import f1_score, classification_report
from tqdm.auto import tqdm
import optuna
import warnings
warnings.filterwarnings('ignore')

# HEF libs
import spacy
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import emoji
# augmentation
import nltk
from nltk.corpus import wordnet
import nlpaug.augmenter.word as naw

# Ensure NLTK assets
try:
    _ = wordnet.synsets("dog")
except Exception:
    import nltk as _nltk
    _nltk.download('wordnet')
    _nltk.download('omw-1.4')

# Seed
SEED = 42
random.seed(SEED); np.random.seed(SEED); torch.manual_seed(SEED)
if torch.cuda.is_available(): torch.cuda.manual_seed_all(SEED)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

# -------------------------
# Config / hyperparams
# -------------------------
BACKBONE = "microsoft/deberta-v3-large"   # change to -large if you have A100
MAX_LEN = 128
BATCH_SIZE = 20        # lower if OOM
EPOCHS = 4
LR = 2e-5
WEIGHT_DECAY = 0.01
NUM_TRIALS_THRESHOLD = 30   # per-class Optuna trials (quick). Increase to 80+ if you want.
TOP_K_CHECKPOINTS = 3

AUGMENT_SYNONYM = True   # lightweight augmentation for rare classes
AUGMENT_PROB = 0.25      # probability to augment a rare-sample
RARE_THRESHOLD = 120     # label support < this is rare

EMOTION_NAMES = [
 'admiration','amusement','anger','annoyance','approval','caring','confusion','curiosity','desire',
 'disappointment','disapproval','disgust','embarrassment','excitement','fear','gratitude','grief',
 'joy','love','nervousness','optimism','pride','realization','relief','remorse','sadness','surprise','neutral'
]
NUM_LABELS = len(EMOTION_NAMES)

# -------------------------
# Load data + basic clean
# -------------------------
print("Loading GoEmotions...")
dataset = load_dataset("google-research-datasets/go_emotions", "simplified")
train_df = dataset['train'].to_pandas()
val_df = dataset['validation'].to_pandas()
test_df = dataset['test'].to_pandas()

# ensure label lists
train_df['labels'] = train_df['labels'].apply(lambda x: [int(i) for i in x])
val_df['labels']   = val_df['labels'].apply(lambda x: [int(i) for i in x])
test_df['labels']  = test_df['labels'].apply(lambda x: [int(i) for i in x])

def clean_text(df):
    df = df.copy()
    df['text'] = df['text'].str.strip()
    df['text'] = df['text'].str.replace(r'\s+', ' ', regex=True)
    return df[df['text'].str.len() > 0]

train_df = clean_text(train_df)
val_df   = clean_text(val_df)
test_df  = clean_text(test_df)

print(len(train_df), len(val_df), len(test_df), "examples")

# -------------------------
# HEF: spaCy + VADER
# -------------------------
print("Loading HEF tools...")
nlp = spacy.load("en_core_web_sm", disable=["ner"])
vader = SentimentIntensityAnalyzer()

def extract_hef_features(text):
    doc = nlp(text)
    pos_counts = {'ADJ':0,'ADV':0,'INTJ':0,'VERB':0,'NOUN':0}
    for tok in doc:
        if tok.pos_ in pos_counts:
            pos_counts[tok.pos_] += 1
    exclam = text.count('!')
    qmarks = text.count('?')
    allcaps = sum(1 for w in text.split() if w.isupper() and len(w) > 1)
    vs = vader.polarity_scores(text)
    emojis = sum(1 for c in text if c in emoji.EMOJI_DATA)
    feat = [
        pos_counts['ADJ'], pos_counts['ADV'], pos_counts['INTJ'],
        pos_counts['VERB'], pos_counts['NOUN'],
        exclam, qmarks, allcaps,
        vs['neg'], vs['neu'], vs['pos'], vs['compound'],
        emojis
    ]
    return np.array(feat, dtype=np.float32)  # HEF_DIM = 13

HEF_DIM = 13

# -------------------------
# Augmentation: synonym replacement (light)
# -------------------------
def synonym_augment(text, p=0.12):
    words = text.split()
    new_words = []
    for w in words:
        if random.random() < p:
            syns = wordnet.synsets(w)
            if syns:
                lemmas = [l.name().replace('_',' ') for s in syns for l in s.lemmas() if l.name().lower() != w.lower()]
                if lemmas:
                    new_words.append(random.choice(lemmas))
                    continue
        new_words.append(w)
    return " ".join(new_words)

# determine rare classes
label_counts = train_df.explode('labels')['labels'].value_counts()
rare_classes = set(label_counts[label_counts < RARE_THRESHOLD].index.tolist())
print("Rare classes (support < {}):".format(RARE_THRESHOLD), sorted(list(rare_classes)))

def maybe_augment(text, labels):
    if not labels: return text
    if any(l in rare_classes for l in labels) and AUGMENT_SYNONYM and random.random() < AUGMENT_PROB:
        return synonym_augment(text, p=0.12)
    return text

# -------------------------
# Tokenizer & Dataset
# -------------------------
print("Preparing tokenizer and datasets...")
tokenizer = AutoTokenizer.from_pretrained(BACKBONE)

class HybridDataset(Dataset):
    def __init__(self, texts, labels, tokenizer, max_len, hef=True, augment=False):
        self.texts = texts
        self.labels = labels
        self.tokenizer = tokenizer
        self.max_len = max_len
        self.hef = hef
        self.augment = augment

    def __len__(self): return len(self.texts)

    def __getitem__(self, idx):
        text = str(self.texts[idx])
        labs = self.labels[idx]
        if self.augment:
            text = maybe_augment(text, labs)

        enc = self.tokenizer(text, padding='max_length', truncation=True, max_length=self.max_len, return_tensors='pt')
        input_ids = enc['input_ids'].squeeze(0)
        attention_mask = enc['attention_mask'].squeeze(0)

        label_vec = torch.zeros(NUM_LABELS, dtype=torch.float)
        for l in labs:
            label_vec[l] = 1.0

        hef_vec = torch.zeros(HEF_DIM, dtype=torch.float)
        if self.hef:
            hef_np = extract_hef_features(text)
            hef_vec = torch.from_numpy(hef_np)

        return {
            "input_ids": input_ids,
            "attention_mask": attention_mask,
            "hef": hef_vec,
            "labels": label_vec
        }

train_dataset = HybridDataset(train_df['text'].tolist(), train_df['labels'].tolist(), tokenizer, MAX_LEN, hef=True, augment=True)
val_dataset   = HybridDataset(val_df['text'].tolist(), val_df['labels'].tolist(), tokenizer, MAX_LEN, hef=True, augment=False)
test_dataset  = HybridDataset(test_df['text'].tolist(), test_df['labels'].tolist(), tokenizer, MAX_LEN, hef=True, augment=False)

# -------------------------
# Weighted sampler
# -------------------------
print("Creating weighted sampler...")
label_counts_tensor = torch.zeros(NUM_LABELS)
for labs in train_df['labels']:
    for l in labs:
        label_counts_tensor[l] += 1

sample_weights = []
for labs in train_df['labels']:
    if len(labs) == 0:
        sample_weights.append(0.0)
    else:
        sample_weights.append(sum([1.0 / (label_counts_tensor[l].item() + 1e-6) for l in labs]))

sampler = WeightedRandomSampler(torch.tensor(sample_weights, dtype=torch.double), num_samples=len(sample_weights), replacement=True)

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, sampler=sampler, num_workers=2)
val_loader   = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=2)
test_loader  = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=2)

# -------------------------
# Model: AutoModel backbone + HEF fusion head
# -------------------------
print("Loading backbone:", BACKBONE)
backbone = AutoModel.from_pretrained(BACKBONE)
hidden_size = backbone.config.hidden_size

class HybridClassifier(nn.Module):
    def __init__(self, backbone, hef_dim, hidden_size, num_labels, proj=512, drop=0.2):
        super().__init__()
        self.backbone = backbone
        self.head = nn.Sequential(
            nn.Linear(hidden_size + hef_dim, proj),
            nn.ReLU(),
            nn.Dropout(drop),
            nn.Linear(proj, num_labels)
        )
    def forward(self, input_ids=None, attention_mask=None, hef=None):
        out = self.backbone(input_ids=input_ids, attention_mask=attention_mask, return_dict=True)
        pooled = out.last_hidden_state[:,0,:]   # CLS-like pooling
        if hef is None:
            hef = torch.zeros((pooled.size(0), HEF_DIM), device=pooled.device)
        x = torch.cat([pooled, hef], dim=-1)
        logits = self.head(x)
        return logits

model = HybridClassifier(backbone, HEF_DIM, hidden_size, NUM_LABELS).to(device)

# -------------------------
# Loss: Autocast-safe Clipped Asymmetric Loss
# -------------------------
import torch.nn.functional as F
class ClippedAsymmetricLoss(nn.Module):
    def __init__(self, gamma_pos=0.0, gamma_neg=1.0, clip=0.05, reduction='mean'):
        super().__init__()
        self.gamma_pos = gamma_pos
        self.gamma_neg = gamma_neg
        self.clip = clip
        self.reduction = reduction
    def forward(self, logits, targets):
        # BCE via logits (stable + autocast-safe)
        bce = F.binary_cross_entropy_with_logits(logits, targets, reduction='none')  # (B,L)
        probs = torch.sigmoid(logits)
        xs_pos = probs
        xs_neg = 1.0 - probs
        if self.clip and self.clip > 0:
            xs_neg = (xs_neg + self.clip).clamp(max=1)
        pt = torch.where(targets==1, xs_pos, xs_neg)
        gamma = torch.where(targets==1, torch.tensor(self.gamma_pos, device=logits.device), torch.tensor(self.gamma_neg, device=logits.device))
        focal_factor = (1.0 - pt) ** gamma
        loss = focal_factor * bce
        if self.reduction == 'mean': return loss.mean()
        if self.reduction == 'sum': return loss.sum()
        return loss

loss_fn = ClippedAsymmetricLoss(gamma_pos=0.0, gamma_neg=1.0, clip=0.05)

# -------------------------
# Optimizer / scheduler / AMP
# -------------------------
optimizer = torch.optim.AdamW(model.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)
total_steps = len(train_loader) * EPOCHS
scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps=int(0.05*total_steps), num_training_steps=total_steps)
scaler = torch.cuda.amp.GradScaler()

# -------------------------
# Train / Eval helpers
# -------------------------
def train_one_epoch(model, loader, optimizer, scheduler, loss_fn, device):
    model.train()
    total_loss = 0.0
    for batch in tqdm(loader, desc="Train"):
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        hef = batch['hef'].to(device)
        labels = batch['labels'].to(device)

        optimizer.zero_grad()
        with torch.cuda.amp.autocast():
            logits = model(input_ids=input_ids, attention_mask=attention_mask, hef=hef)
            loss = loss_fn(logits, labels)
        scaler.scale(loss).backward()
        scaler.unscale_(optimizer)
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        scaler.step(optimizer)
        scaler.update()
        scheduler.step()
        total_loss += loss.item()
    return total_loss / len(loader)

def predict_probs(model, loader, device):
    model.eval()
    probs_list, labels_list = [], []
    with torch.no_grad():
        for batch in tqdm(loader, desc="Predict"):
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            hef = batch['hef'].to(device)
            labels = batch['labels'].cpu().numpy()
            logits = model(input_ids=input_ids, attention_mask=attention_mask, hef=hef)
            probs = torch.sigmoid(logits).cpu().numpy()
            probs_list.append(probs)
            labels_list.append(labels)
    return np.vstack(probs_list), np.vstack(labels_list)

# -------------------------
# Per-class threshold tuning (Optuna)
# -------------------------
def tune_thresholds_per_class(val_probs, val_labels, n_trials=NUM_TRIALS_THRESHOLD, seed=SEED):
    thresholds = np.zeros(NUM_LABELS)
    def objective_factory(col):
        def objective(trial):
            t = trial.suggest_float("t", 0.01, 0.9)
            preds = (val_probs[:, col] >= t).astype(int)
            return f1_score(val_labels[:, col], preds, zero_division=0)
        return objective
    for c in range(NUM_LABELS):
        study = optuna.create_study(direction="maximize", sampler=optuna.samplers.TPESampler(seed=seed))
        study.optimize(objective_factory(c), n_trials=n_trials, show_progress_bar=False)
        thresholds[c] = study.best_trial.params['t']
    return thresholds

# -------------------------
# Main training loop with checkpointing
# -------------------------
checkpoint_records = []  # (val_micro, path, thresholds)
best_val_micro = 0.0

for epoch in range(EPOCHS):
    print(f"\nEpoch {epoch+1}/{EPOCHS}")
    train_loss = train_one_epoch(model, train_loader, optimizer, scheduler, loss_fn, device)
    print("Train loss:", train_loss)

    val_probs, val_labels = predict_probs(model, val_loader, device)
    thresholds = tune_thresholds_per_class(val_probs, val_labels, n_trials=NUM_TRIALS_THRESHOLD)
    val_preds = (val_probs >= thresholds).astype(int)
    val_micro = f1_score(val_labels, val_preds, average='micro', zero_division=0)
    val_macro = f1_score(val_labels, val_preds, average='macro', zero_division=0)
    print(f"Val micro-F1: {val_micro:.4f} | Val macro-F1: {val_macro:.4f}")

    ckpt = f"ckpt_epoch{epoch+1:02d}_micro{val_micro:.4f}.pt"
    torch.save(model.state_dict(), ckpt)
    checkpoint_records.append((val_micro, ckpt, thresholds.copy()))
    checkpoint_records = sorted(checkpoint_records, key=lambda x: x[0], reverse=True)[:TOP_K_CHECKPOINTS]

    if val_micro > best_val_micro:
        best_val_micro = val_micro
        best_thresholds_best = thresholds.copy()

    print("Top checkpoints:", [(r[0], r[1]) for r in checkpoint_records])

print("\nTraining finished. Best val micro-F1:", best_val_micro)

# -------------------------
# Ensemble top checkpoints on test set
# -------------------------
print("Ensembling top checkpoints...")
probs_accum = None
labels_accum = None
th_stack = []
for score, ckpt_path, th in checkpoint_records:
    state = torch.load(ckpt_path, map_location=device)
    model.load_state_dict(state)
    model.to(device)
    model.eval()
    probs, labels = predict_probs(model, test_loader, device)
    if probs_accum is None:
        probs_accum = probs
        labels_accum = labels
    else:
        probs_accum += probs
    th_stack.append(th)

ensemble_probs = probs_accum / len(checkpoint_records)
if th_stack:
    ensemble_thresholds = np.mean(np.stack(th_stack, axis=0), axis=0)
else:
    ensemble_thresholds = best_thresholds_best

test_preds = (ensemble_probs >= ensemble_thresholds).astype(int)
micro = f1_score(labels_accum, test_preds, average='micro', zero_division=0)
macro = f1_score(labels_accum, test_preds, average='macro', zero_division=0)
weighted = f1_score(labels_accum, test_preds, average='weighted', zero_division=0)

print(f"Ensemble Test Micro-F1: {micro:.4f} | Macro-F1: {macro:.4f} | Weighted-F1: {weighted:.4f}")
print("\nClassification report (ensemble):")
print(classification_report(labels_accum, test_preds, target_names=EMOTION_NAMES, zero_division=0))

# -------------------------
# Inference helper
# -------------------------
def predict_text(text, model, tokenizer, device, thresholds, hef_enabled=True):
    model.eval()
    enc = tokenizer(text, padding='max_length', truncation=True, max_length=MAX_LEN, return_tensors='pt')
    input_ids = enc['input_ids'].to(device); attention_mask = enc['attention_mask'].to(device)
    hef_tensor = torch.from_numpy(extract_hef_features(text)).unsqueeze(0).to(device) if hef_enabled else torch.zeros((1,HEF_DIM), device=device)
    with torch.no_grad():
        logits = model(input_ids=input_ids, attention_mask=attention_mask, hef=hef_tensor)
        probs = torch.sigmoid(logits).cpu().numpy()[0]
    preds = [(EMOTION_NAMES[i], float(probs[i])) for i in range(NUM_LABELS) if probs[i] >= thresholds[i]]
    preds.sort(key=lambda x: x[1], reverse=True)
    return preds

print("\nExample predictions:")
for txt in ["I am thrilled to see you!", "I hate this so much.", "Thanks for your help."]:
    print(txt, "->", predict_text(txt, model, tokenizer, device, ensemble_thresholds))
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# Device: cuda
# Loading GoEmotions...
# README.md: 0.00B [00:00, ?B/s]
# simplified/train-00000-of-00001.parquet:   0%|          | 0.00/2.77M [00:00<?, ?B/s]
# simplified/validation-00000-of-00001.par(…):   0%|          | 0.00/350k [00:00<?, ?B/s]
# simplified/test-00000-of-00001.parquet:   0%|          | 0.00/347k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/43410 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/5426 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/5427 [00:00<?, ? examples/s]
# 43410 5426 5427 examples
# Loading HEF tools...
# Rare classes (support < 120): [16, 21]
# Preparing tokenizer and datasets...
# tokenizer_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/580 [00:00<?, ?B/s]
# spm.model:   0%|          | 0.00/2.46M [00:00<?, ?B/s]
# Creating weighted sampler...
# Loading backbone: microsoft/deberta-v3-large
# pytorch_model.bin:   0%|          | 0.00/874M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/874M [00:00<?, ?B/s]
# Epoch 1/4
# Train:   0%|          | 0/2171 [00:00<?, ?it/s]
# Train loss: 0.08245000745526304
# Predict:   0%|          | 0/272 [00:00<?, ?it/s]
# [I 2025-12-07 07:12:01,389] A new study created in memory with name: no-name-cd1d697b-eb00-4c00-a9de-13d65bd52729
# [I 2025-12-07 07:12:01,415] Trial 0 finished with value: 0.6846846846846847 and parameters: {'t': 0.34334070577415265}. Best is trial 0 with value: 0.6846846846846847.
# [I 2025-12-07 07:12:01,422] Trial 1 finished with value: 0.618421052631579 and parameters: {'t': 0.8561357327048255}. Best is trial 0 with value: 0.6846846846846847.
# [I 2025-12-07 07:12:01,427] Trial 2 finished with value: 0.7251336898395722 and parameters: {'t': 0.6614746082121505}. Best is trial 2 with value: 0.7251336898395722.
# [I 2025-12-07 07:12:01,432] Trial 3 finished with value: 0.7291866028708134 and parameters: {'t': 0.5428060509353626}. Best is trial 3 with value: 0.7291866028708134.
# [I 2025-12-07 07:12:01,437] Trial 4 finished with value: 0.4575036425449247 and parameters: {'t': 0.14885658999376852}. Best is trial 3 with value: 0.7291866028708134.
# [I 2025-12-07 07:12:01,443] Trial 5 finished with value: 0.4575036425449247 and parameters: {'t': 0.14883512309922037}. Best is trial 3 with value: 0.7291866028708134.
# [I 2025-12-07 07:12:01,447] Trial 6 finished with value: 0.2139555359894343 and parameters: {'t': 0.06169441482969752}. Best is trial 3 with value: 0.7291866028708134.
# [I 2025-12-07 07:12:01,453] Trial 7 finished with value: 0.6855123674911661 and parameters: {'t': 0.7808967697396924}. Best is trial 3 with value: 0.7291866028708134.
# [I 2025-12-07 07:12:01,458] Trial 8 finished with value: 0.7279693486590039 and parameters: {'t': 0.5449923604514558}. Best is trial 3 with value: 0.7291866028708134.
# [I 2025-12-07 07:12:01,462] Trial 9 finished with value: 0.7299270072992701 and parameters: {'t': 0.6401845942384805}. Best is trial 9 with value: 0.7299270072992701.
# [I 2025-12-07 07:12:01,475] Trial 10 finished with value: 0.6510219530658592 and parameters: {'t': 0.28709734798494785}. Best is trial 9 with value: 0.7299270072992701.
# [I 2025-12-07 07:12:01,485] Trial 11 finished with value: 0.7283126787416587 and parameters: {'t': 0.533881569240642}. Best is trial 9 with value: 0.7299270072992701.
# [I 2025-12-07 07:12:01,494] Trial 12 finished with value: 0.7007786429365962 and parameters: {'t': 0.7110244956960703}. Best is trial 9 with value: 0.7299270072992701.
# [I 2025-12-07 07:12:01,502] Trial 13 finished with value: 0.7136322049405307 and parameters: {'t': 0.4745622311493771}. Best is trial 9 with value: 0.7299270072992701.
# [I 2025-12-07 07:12:01,510] Trial 14 finished with value: 0.732994923857868 and parameters: {'t': 0.6081360751736614}. Best is trial 14 with value: 0.732994923857868.
# [I 2025-12-07 07:12:01,517] Trial 15 finished with value: 0.7251336898395722 and parameters: {'t': 0.6625465265200234}. Best is trial 14 with value: 0.732994923857868.
# [I 2025-12-07 07:12:01,523] Trial 16 finished with value: 0.6988973706530959 and parameters: {'t': 0.3771222467575376}. Best is trial 14 with value: 0.732994923857868.
# [I 2025-12-07 07:12:01,530] Trial 17 finished with value: 0.6005361930294906 and parameters: {'t': 0.8656350974252595}. Best is trial 14 with value: 0.732994923857868.
# [I 2025-12-07 07:12:01,537] Trial 18 finished with value: 0.69327251995439 and parameters: {'t': 0.7377994176136988}. Best is trial 14 with value: 0.732994923857868.
# [I 2025-12-07 07:12:01,545] Trial 19 finished with value: 0.7283582089552239 and parameters: {'t': 0.594306498458243}. Best is trial 14 with value: 0.732994923857868.
# [I 2025-12-07 07:12:01,555] Trial 20 finished with value: 0.7270854788877446 and parameters: {'t': 0.6300696100853953}. Best is trial 14 with value: 0.732994923857868.
# [I 2025-12-07 07:12:01,566] Trial 21 finished with value: 0.7126230975828111 and parameters: {'t': 0.4368843387743694}. Best is trial 14 with value: 0.732994923857868.
# [I 2025-12-07 07:12:01,574] Trial 22 finished with value: 0.7233238904627006 and parameters: {'t': 0.5240360747326959}. Best is trial 14 with value: 0.732994923857868.
# [I 2025-12-07 07:12:01,582] Trial 23 finished with value: 0.6746698679471789 and parameters: {'t': 0.7937604143713985}. Best is trial 14 with value: 0.732994923857868.
# [I 2025-12-07 07:12:01,589] Trial 24 finished with value: 0.7139013452914799 and parameters: {'t': 0.44072122911610734}. Best is trial 14 with value: 0.732994923857868.
# [I 2025-12-07 07:12:01,596] Trial 25 finished with value: 0.7283582089552239 and parameters: {'t': 0.5944610782514047}. Best is trial 14 with value: 0.732994923857868.
# [I 2025-12-07 07:12:01,603] Trial 26 finished with value: 0.7078280044101434 and parameters: {'t': 0.7011367233323217}. Best is trial 14 with value: 0.732994923857868.
# [I 2025-12-07 07:12:01,611] Trial 27 finished with value: 0.729227761485826 and parameters: {'t': 0.5716097502147292}. Best is trial 14 with value: 0.732994923857868.
# [I 2025-12-07 07:12:01,619] Trial 28 finished with value: 0.6792899408284023 and parameters: {'t': 0.7861798280427756}. Best is trial 14 with value: 0.732994923857868.
# [I 2025-12-07 07:12:01,627] Trial 29 finished with value: 0.6859983429991715 and parameters: {'t': 0.35495884161692515}. Best is trial 14 with value: 0.732994923857868.
# [I 2025-12-07 07:12:01,630] A new study created in memory with name: no-name-32dc20c9-28b8-4386-8841-ca295a1f3c12
# [I 2025-12-07 07:12:01,637] Trial 0 finished with value: 0.7837078651685393 and parameters: {'t': 0.34334070577415265}. Best is trial 0 with value: 0.7837078651685393.
# [I 2025-12-07 07:12:01,643] Trial 1 finished with value: 0.7178502879078695 and parameters: {'t': 0.8561357327048255}. Best is trial 0 with value: 0.7837078651685393.
# [I 2025-12-07 07:12:01,651] Trial 2 finished with value: 0.8050314465408805 and parameters: {'t': 0.6614746082121505}. Best is trial 2 with value: 0.8050314465408805.
# [I 2025-12-07 07:12:01,657] Trial 3 finished with value: 0.7970149253731343 and parameters: {'t': 0.5428060509353626}. Best is trial 2 with value: 0.8050314465408805.
# [I 2025-12-07 07:12:01,663] Trial 4 finished with value: 0.6178686759956943 and parameters: {'t': 0.14885658999376852}. Best is trial 2 with value: 0.8050314465408805.
# [I 2025-12-07 07:12:01,668] Trial 5 finished with value: 0.6178686759956943 and parameters: {'t': 0.14883512309922037}. Best is trial 2 with value: 0.8050314465408805.
# [I 2025-12-07 07:12:01,672] Trial 6 finished with value: 0.13750571037003198 and parameters: {'t': 0.06169441482969752}. Best is trial 2 with value: 0.8050314465408805.
# [I 2025-12-07 07:12:01,677] Trial 7 finished with value: 0.770293609671848 and parameters: {'t': 0.7808967697396924}. Best is trial 2 with value: 0.8050314465408805.
# [I 2025-12-07 07:12:01,681] Trial 8 finished with value: 0.7970149253731343 and parameters: {'t': 0.5449923604514558}. Best is trial 2 with value: 0.8050314465408805.
# [I 2025-12-07 07:12:01,686] Trial 9 finished with value: 0.8062015503875969 and parameters: {'t': 0.6401845942384805}. Best is trial 9 with value: 0.8062015503875969.
# [I 2025-12-07 07:12:01,692] Trial 10 finished with value: 0.7770177838577291 and parameters: {'t': 0.28709734798494785}. Best is trial 9 with value: 0.8062015503875969.
# [I 2025-12-07 07:12:01,701] Trial 11 finished with value: 0.7954911433172303 and parameters: {'t': 0.6891516983356998}. Best is trial 9 with value: 0.8062015503875969.
# [I 2025-12-07 07:12:01,710] Trial 12 finished with value: 0.8117283950617284 and parameters: {'t': 0.6295448449889056}. Best is trial 12 with value: 0.8117283950617284.
# [I 2025-12-07 07:12:01,718] Trial 13 finished with value: 0.7964860907759883 and parameters: {'t': 0.4658980749166799}. Best is trial 12 with value: 0.8117283950617284.
# [I 2025-12-07 07:12:01,726] Trial 14 finished with value: 0.8037974683544303 and parameters: {'t': 0.6711440463288574}. Best is trial 12 with value: 0.8117283950617284.
# [I 2025-12-07 07:12:01,733] Trial 15 finished with value: 0.806060606060606 and parameters: {'t': 0.5897163515651863}. Best is trial 12 with value: 0.8117283950617284.
# [I 2025-12-07 07:12:01,740] Trial 16 finished with value: 0.7959770114942529 and parameters: {'t': 0.3991980282850679}. Best is trial 12 with value: 0.8117283950617284.
# [I 2025-12-07 07:12:01,747] Trial 17 finished with value: 0.770293609671848 and parameters: {'t': 0.7800361365962762}. Best is trial 12 with value: 0.8117283950617284.
# [I 2025-12-07 07:12:01,754] Trial 18 finished with value: 0.7178502879078695 and parameters: {'t': 0.856728710152719}. Best is trial 12 with value: 0.8117283950617284.
# [I 2025-12-07 07:12:01,762] Trial 19 finished with value: 0.7982326951399117 and parameters: {'t': 0.4786669293010844}. Best is trial 12 with value: 0.8117283950617284.
# [I 2025-12-07 07:12:01,771] Trial 20 finished with value: 0.7749576988155669 and parameters: {'t': 0.7492995414003145}. Best is trial 12 with value: 0.8117283950617284.
# [I 2025-12-07 07:12:11,795] Trial 21 finished with value: 0.8054298642533937 and parameters: {'t': 0.5783009584816577}. Best is trial 12 with value: 0.8117283950617284.
# [I 2025-12-07 07:12:11,815] Trial 22 finished with value: 0.8092307692307692 and parameters: {'t': 0.6176576095917179}. Best is trial 12 with value: 0.8117283950617284.
# [I 2025-12-07 07:12:11,830] Trial 23 finished with value: 0.8092307692307692 and parameters: {'t': 0.6207765970305764}. Best is trial 12 with value: 0.8117283950617284.
# [I 2025-12-07 07:12:11,844] Trial 24 finished with value: 0.7833333333333333 and parameters: {'t': 0.7223783708218657}. Best is trial 12 with value: 0.8117283950617284.
# [I 2025-12-07 07:12:11,859] Trial 25 finished with value: 0.7976366322008862 and parameters: {'t': 0.48889876683247785}. Best is trial 12 with value: 0.8117283950617284.
# [I 2025-12-07 07:12:11,873] Trial 26 finished with value: 0.8079877112135176 and parameters: {'t': 0.6157349646725652}. Best is trial 12 with value: 0.8117283950617284.
# [I 2025-12-07 07:12:11,880] Trial 27 finished with value: 0.7903682719546742 and parameters: {'t': 0.36854878266798274}. Best is trial 12 with value: 0.8117283950617284.
# [I 2025-12-07 07:12:11,888] Trial 28 finished with value: 0.8023774145616642 and parameters: {'t': 0.5150420247064061}. Best is trial 12 with value: 0.8117283950617284.
# [I 2025-12-07 07:12:11,896] Trial 29 finished with value: 0.7794729542302358 and parameters: {'t': 0.318073723097862}. Best is trial 12 with value: 0.8117283950617284.
# [I 2025-12-07 07:12:11,900] A new study created in memory with name: no-name-5654e0fd-2ff6-4f5e-8ba3-3587f439df2a
# [I 2025-12-07 07:12:11,906] Trial 0 finished with value: 0.43669724770642204 and parameters: {'t': 0.34334070577415265}. Best is trial 0 with value: 0.43669724770642204.
# [I 2025-12-07 07:12:11,912] Trial 1 finished with value: 0.020202020202020204 and parameters: {'t': 0.8561357327048255}. Best is trial 0 with value: 0.43669724770642204.
# [I 2025-12-07 07:12:11,917] Trial 2 finished with value: 0.42483660130718953 and parameters: {'t': 0.6614746082121505}. Best is trial 0 with value: 0.43669724770642204.
# [I 2025-12-07 07:12:11,921] Trial 3 finished with value: 0.49444444444444446 and parameters: {'t': 0.5428060509353626}. Best is trial 3 with value: 0.49444444444444446.
# [I 2025-12-07 07:12:11,926] Trial 4 finished with value: 0.29360967184801384 and parameters: {'t': 0.14885658999376852}. Best is trial 3 with value: 0.49444444444444446.
# [I 2025-12-07 07:12:11,931] Trial 5 finished with value: 0.29360967184801384 and parameters: {'t': 0.14883512309922037}. Best is trial 3 with value: 0.49444444444444446.
# [I 2025-12-07 07:12:11,936] Trial 6 finished with value: 0.11786259541984732 and parameters: {'t': 0.06169441482969752}. Best is trial 3 with value: 0.49444444444444446.
# [I 2025-12-07 07:12:11,940] Trial 7 finished with value: 0.301255230125523 and parameters: {'t': 0.7808967697396924}. Best is trial 3 with value: 0.49444444444444446.
# [I 2025-12-07 07:12:11,945] Trial 8 finished with value: 0.48739495798319327 and parameters: {'t': 0.5449923604514558}. Best is trial 3 with value: 0.49444444444444446.
# [I 2025-12-07 07:12:11,949] Trial 9 finished with value: 0.43450479233226835 and parameters: {'t': 0.6401845942384805}. Best is trial 3 with value: 0.49444444444444446.
# [I 2025-12-07 07:12:11,955] Trial 10 finished with value: 0.4621676891615542 and parameters: {'t': 0.3881167734237996}. Best is trial 3 with value: 0.49444444444444446.
# [I 2025-12-07 07:12:11,961] Trial 11 finished with value: 0.5080213903743316 and parameters: {'t': 0.526751660469508}. Best is trial 11 with value: 0.5080213903743316.
# [I 2025-12-07 07:12:11,966] Trial 12 finished with value: 0.5036674816625917 and parameters: {'t': 0.47780499605238125}. Best is trial 11 with value: 0.5080213903743316.
# [I 2025-12-07 07:12:11,977] Trial 13 finished with value: 0.42086956521739133 and parameters: {'t': 0.3184270184856138}. Best is trial 11 with value: 0.5080213903743316.
# [I 2025-12-07 07:12:11,984] Trial 14 finished with value: 0.5036674816625917 and parameters: {'t': 0.476104643892708}. Best is trial 11 with value: 0.5080213903743316.
# [I 2025-12-07 07:12:11,990] Trial 15 finished with value: 0.42483660130718953 and parameters: {'t': 0.6625465265200234}. Best is trial 11 with value: 0.5080213903743316.
# [I 2025-12-07 07:12:11,998] Trial 16 finished with value: 0.3976083707025411 and parameters: {'t': 0.26484993046417205}. Best is trial 11 with value: 0.5080213903743316.
# [I 2025-12-07 07:12:12,007] Trial 17 finished with value: 0.48130841121495327 and parameters: {'t': 0.45245014831606356}. Best is trial 11 with value: 0.5080213903743316.
# [I 2025-12-07 07:12:12,015] Trial 18 finished with value: 0.47674418604651164 and parameters: {'t': 0.568916638204593}. Best is trial 11 with value: 0.5080213903743316.
# [I 2025-12-07 07:12:12,022] Trial 19 finished with value: 0.33064516129032256 and parameters: {'t': 0.7579394926601408}. Best is trial 11 with value: 0.5080213903743316.
# [I 2025-12-07 07:12:12,030] Trial 20 finished with value: 0.48372093023255813 and parameters: {'t': 0.4500646991276143}. Best is trial 11 with value: 0.5080213903743316.
# [I 2025-12-07 07:12:12,039] Trial 21 finished with value: 0.5115089514066496 and parameters: {'t': 0.5070870103935683}. Best is trial 21 with value: 0.5115089514066496.
# [I 2025-12-07 07:12:12,048] Trial 22 finished with value: 0.47305389221556887 and parameters: {'t': 0.5938167023362345}. Best is trial 21 with value: 0.5115089514066496.
# [I 2025-12-07 07:12:12,057] Trial 23 finished with value: 0.5036674816625917 and parameters: {'t': 0.4761026623271453}. Best is trial 21 with value: 0.5115089514066496.
# [I 2025-12-07 07:12:12,065] Trial 24 finished with value: 0.37988826815642457 and parameters: {'t': 0.24342152714388485}. Best is trial 21 with value: 0.5115089514066496.
# [I 2025-12-07 07:12:12,075] Trial 25 finished with value: 0.3712121212121212 and parameters: {'t': 0.7295856202042796}. Best is trial 21 with value: 0.5115089514066496.
# [I 2025-12-07 07:12:12,084] Trial 26 finished with value: 0.5052083333333334 and parameters: {'t': 0.5128959219831033}. Best is trial 21 with value: 0.5115089514066496.
# [I 2025-12-07 07:12:12,092] Trial 27 finished with value: 0.45691382765531063 and parameters: {'t': 0.3787886189932742}. Best is trial 21 with value: 0.5115089514066496.
# [I 2025-12-07 07:12:12,101] Trial 28 finished with value: 0.4339622641509434 and parameters: {'t': 0.6251389136440347}. Best is trial 21 with value: 0.5115089514066496.
# [I 2025-12-07 07:12:12,110] Trial 29 finished with value: 0.4708333333333333 and parameters: {'t': 0.3991956215559259}. Best is trial 21 with value: 0.5115089514066496.
# [I 2025-12-07 07:12:12,112] A new study created in memory with name: no-name-44bf8f8c-afdf-423e-9365-feabc43afe4f
# [I 2025-12-07 07:12:12,117] Trial 0 finished with value: 0.38783269961977185 and parameters: {'t': 0.34334070577415265}. Best is trial 0 with value: 0.38783269961977185.
# [I 2025-12-07 07:12:12,122] Trial 1 finished with value: 0.0 and parameters: {'t': 0.8561357327048255}. Best is trial 0 with value: 0.38783269961977185.
# [I 2025-12-07 07:12:12,127] Trial 2 finished with value: 0.006535947712418301 and parameters: {'t': 0.6614746082121505}. Best is trial 0 with value: 0.38783269961977185.
# [I 2025-12-07 07:12:12,132] Trial 3 finished with value: 0.15041782729805014 and parameters: {'t': 0.5428060509353626}. Best is trial 0 with value: 0.38783269961977185.
# [I 2025-12-07 07:12:12,136] Trial 4 finished with value: 0.24234234234234234 and parameters: {'t': 0.14885658999376852}. Best is trial 0 with value: 0.38783269961977185.
# [I 2025-12-07 07:12:12,143] Trial 5 finished with value: 0.24234234234234234 and parameters: {'t': 0.14883512309922037}. Best is trial 0 with value: 0.38783269961977185.
# [I 2025-12-07 07:12:12,150] Trial 6 finished with value: 0.11969575660528423 and parameters: {'t': 0.06169441482969752}. Best is trial 0 with value: 0.38783269961977185.
# [I 2025-12-07 07:12:12,155] Trial 7 finished with value: 0.0 and parameters: {'t': 0.7808967697396924}. Best is trial 0 with value: 0.38783269961977185.
# [I 2025-12-07 07:12:12,163] Trial 8 finished with value: 0.15083798882681565 and parameters: {'t': 0.5449923604514558}. Best is trial 0 with value: 0.38783269961977185.
# [I 2025-12-07 07:12:12,171] Trial 9 finished with value: 0.038461538461538464 and parameters: {'t': 0.6401845942384805}. Best is trial 0 with value: 0.38783269961977185.
# [I 2025-12-07 07:12:12,181] Trial 10 finished with value: 0.38783269961977185 and parameters: {'t': 0.34328420076205823}. Best is trial 0 with value: 0.38783269961977185.
# [I 2025-12-07 07:12:12,187] Trial 11 finished with value: 0.38461538461538464 and parameters: {'t': 0.3459072884629457}. Best is trial 0 with value: 0.38783269961977185.
# [I 2025-12-07 07:12:12,193] Trial 12 finished with value: 0.379746835443038 and parameters: {'t': 0.32256276820854246}. Best is trial 0 with value: 0.38783269961977185.
# [I 2025-12-07 07:12:12,199] Trial 13 finished with value: 0.3854748603351955 and parameters: {'t': 0.3666076529956487}. Best is trial 0 with value: 0.38783269961977185.
# [I 2025-12-07 07:12:12,205] Trial 14 finished with value: 0.337722695584818 and parameters: {'t': 0.2437320931970059}. Best is trial 0 with value: 0.38783269961977185.
# [I 2025-12-07 07:12:12,210] Trial 15 finished with value: 0.33528265107212474 and parameters: {'t': 0.4408634602155529}. Best is trial 0 with value: 0.38783269961977185.
# [I 2025-12-07 07:12:12,216] Trial 16 finished with value: 0.33158289572393096 and parameters: {'t': 0.23734467830102685}. Best is trial 0 with value: 0.38783269961977185.
# [I 2025-12-07 07:12:12,222] Trial 17 finished with value: 0.3053763440860215 and parameters: {'t': 0.46822253701315036}. Best is trial 0 with value: 0.38783269961977185.
# [I 2025-12-07 07:12:12,227] Trial 18 finished with value: 0.3410728582866293 and parameters: {'t': 0.2507888489945687}. Best is trial 0 with value: 0.38783269961977185.
# [I 2025-12-07 07:12:12,233] Trial 19 finished with value: 0.105777622621749 and parameters: {'t': 0.02172729189237288}. Best is trial 0 with value: 0.38783269961977185.
# [I 2025-12-07 07:12:12,239] Trial 20 finished with value: 0.3492063492063492 and parameters: {'t': 0.42045365597944573}. Best is trial 0 with value: 0.38783269961977185.
# [I 2025-12-07 07:12:12,249] Trial 21 finished with value: 0.3780160857908847 and parameters: {'t': 0.3560167112448386}. Best is trial 0 with value: 0.38783269961977185.
# [I 2025-12-07 07:12:12,256] Trial 22 finished with value: 0.24056603773584906 and parameters: {'t': 0.49624560023742736}. Best is trial 0 with value: 0.38783269961977185.
# [I 2025-12-07 07:12:12,262] Trial 23 finished with value: 0.3775811209439528 and parameters: {'t': 0.38077068109630846}. Best is trial 0 with value: 0.38783269961977185.
# [I 2025-12-07 07:12:12,268] Trial 24 finished with value: 0.36555023923444974 and parameters: {'t': 0.28349270381446423}. Best is trial 0 with value: 0.38783269961977185.
# [I 2025-12-07 07:12:12,274] Trial 25 finished with value: 0.26833073322932915 and parameters: {'t': 0.17026986643343528}. Best is trial 0 with value: 0.38783269961977185.
# [I 2025-12-07 07:12:12,279] Trial 26 finished with value: 0.05063291139240506 and parameters: {'t': 0.6135697748513107}. Best is trial 0 with value: 0.38783269961977185.
# [I 2025-12-07 07:12:12,285] Trial 27 finished with value: 0.37333333333333335 and parameters: {'t': 0.3819785528716481}. Best is trial 0 with value: 0.38783269961977185.
# [I 2025-12-07 07:12:12,291] Trial 28 finished with value: 0.29088714544357275 and parameters: {'t': 0.19749212940085487}. Best is trial 0 with value: 0.38783269961977185.
# [I 2025-12-07 07:12:12,297] Trial 29 finished with value: 0.0 and parameters: {'t': 0.8055819516755753}. Best is trial 0 with value: 0.38783269961977185.
# [I 2025-12-07 07:12:12,298] A new study created in memory with name: no-name-6c7eb07e-ece8-47db-b448-16db6d28b2a4
# [I 2025-12-07 07:12:12,303] Trial 0 finished with value: 0.3371868978805395 and parameters: {'t': 0.34334070577415265}. Best is trial 0 with value: 0.3371868978805395.
# [I 2025-12-07 07:12:12,307] Trial 1 finished with value: 0.10352941176470588 and parameters: {'t': 0.8561357327048255}. Best is trial 0 with value: 0.3371868978805395.
# [I 2025-12-07 07:12:12,311] Trial 2 finished with value: 0.2711864406779661 and parameters: {'t': 0.6614746082121505}. Best is trial 0 with value: 0.3371868978805395.
# [I 2025-12-07 07:12:12,315] Trial 3 finished with value: 0.3054187192118227 and parameters: {'t': 0.5428060509353626}. Best is trial 0 with value: 0.3371868978805395.
# [I 2025-12-07 07:12:12,321] Trial 4 finished with value: 0.2474074074074074 and parameters: {'t': 0.14885658999376852}. Best is trial 0 with value: 0.3371868978805395.
# [I 2025-12-07 07:12:12,326] Trial 5 finished with value: 0.2472242783123612 and parameters: {'t': 0.14883512309922037}. Best is trial 0 with value: 0.3371868978805395.
# [I 2025-12-07 07:12:12,332] Trial 6 finished with value: 0.15103671295415635 and parameters: {'t': 0.06169441482969752}. Best is trial 0 with value: 0.3371868978805395.
# [I 2025-12-07 07:12:12,336] Trial 7 finished with value: 0.1810344827586207 and parameters: {'t': 0.7808967697396924}. Best is trial 0 with value: 0.3371868978805395.
# [I 2025-12-07 07:12:12,340] Trial 8 finished with value: 0.30363036303630364 and parameters: {'t': 0.5449923604514558}. Best is trial 0 with value: 0.3371868978805395.
# [I 2025-12-07 07:12:12,344] Trial 9 finished with value: 0.28305400372439476 and parameters: {'t': 0.6401845942384805}. Best is trial 0 with value: 0.3371868978805395.
# [I 2025-12-07 07:12:12,349] Trial 10 finished with value: 0.3371868978805395 and parameters: {'t': 0.34328420076205823}. Best is trial 0 with value: 0.3371868978805395.
# [I 2025-12-07 07:12:12,355] Trial 11 finished with value: 0.33852140077821014 and parameters: {'t': 0.3459072884629457}. Best is trial 11 with value: 0.33852140077821014.
# [I 2025-12-07 07:12:12,360] Trial 12 finished with value: 0.3318140382862352 and parameters: {'t': 0.3246486786347696}. Best is trial 11 with value: 0.33852140077821014.
# [I 2025-12-07 07:12:12,365] Trial 13 finished with value: 0.33962264150943394 and parameters: {'t': 0.3666076529956487}. Best is trial 13 with value: 0.33962264150943394.
# [I 2025-12-07 07:12:12,375] Trial 14 finished with value: 0.34491634491634493 and parameters: {'t': 0.4324187172533477}. Best is trial 14 with value: 0.34491634491634493.
# [I 2025-12-07 07:12:12,382] Trial 15 finished with value: 0.3453038674033149 and parameters: {'t': 0.4606150742299839}. Best is trial 15 with value: 0.3453038674033149.
# [I 2025-12-07 07:12:12,388] Trial 16 finished with value: 0.3255131964809384 and parameters: {'t': 0.4888638170310527}. Best is trial 15 with value: 0.3453038674033149.
# [I 2025-12-07 07:12:12,394] Trial 17 finished with value: 0.2899138367967562 and parameters: {'t': 0.1965001147367108}. Best is trial 15 with value: 0.3453038674033149.
# [I 2025-12-07 07:12:12,399] Trial 18 finished with value: 0.26666666666666666 and parameters: {'t': 0.6727482005111547}. Best is trial 15 with value: 0.3453038674033149.
# [I 2025-12-07 07:12:12,405] Trial 19 finished with value: 0.3446327683615819 and parameters: {'t': 0.4721552955820232}. Best is trial 15 with value: 0.3453038674033149.
# [I 2025-12-07 07:12:12,410] Trial 20 finished with value: 0.32057105775470474 and parameters: {'t': 0.24386047689229445}. Best is trial 15 with value: 0.3453038674033149.
# [I 2025-12-07 07:12:12,416] Trial 21 finished with value: 0.34354194407456723 and parameters: {'t': 0.443735553566672}. Best is trial 15 with value: 0.3453038674033149.
# [I 2025-12-07 07:12:12,421] Trial 22 finished with value: 0.3480453972257251 and parameters: {'t': 0.4266089408831978}. Best is trial 22 with value: 0.3480453972257251.
# [I 2025-12-07 07:12:12,427] Trial 23 finished with value: 0.3029259896729776 and parameters: {'t': 0.5761350609591923}. Best is trial 22 with value: 0.3480453972257251.
# [I 2025-12-07 07:12:12,433] Trial 24 finished with value: 0.34738186462324394 and parameters: {'t': 0.43071546592557436}. Best is trial 22 with value: 0.3480453972257251.
# [I 2025-12-07 07:12:12,442] Trial 25 finished with value: 0.3264705882352941 and parameters: {'t': 0.27086909610617926}. Best is trial 22 with value: 0.3480453972257251.
# [I 2025-12-07 07:12:12,450] Trial 26 finished with value: 0.3472222222222222 and parameters: {'t': 0.3982169908740508}. Best is trial 22 with value: 0.3480453972257251.
# [I 2025-12-07 07:12:12,456] Trial 27 finished with value: 0.34579439252336447 and parameters: {'t': 0.4018979406655171}. Best is trial 22 with value: 0.3480453972257251.
# [I 2025-12-07 07:12:12,463] Trial 28 finished with value: 0.32558139534883723 and parameters: {'t': 0.26942789902724096}. Best is trial 22 with value: 0.3480453972257251.
# [I 2025-12-07 07:12:12,470] Trial 29 finished with value: 0.2862190812720848 and parameters: {'t': 0.5951427818545754}. Best is trial 22 with value: 0.3480453972257251.
# [I 2025-12-07 07:12:12,472] A new study created in memory with name: no-name-97839c9c-3c41-433c-9718-93f1f6ecc65b
# [I 2025-12-07 07:12:12,478] Trial 0 finished with value: 0.4819277108433735 and parameters: {'t': 0.34334070577415265}. Best is trial 0 with value: 0.4819277108433735.
# [I 2025-12-07 07:12:12,484] Trial 1 finished with value: 0.3671497584541063 and parameters: {'t': 0.8561357327048255}. Best is trial 0 with value: 0.4819277108433735.
# [I 2025-12-07 07:12:12,489] Trial 2 finished with value: 0.49264705882352944 and parameters: {'t': 0.6614746082121505}. Best is trial 2 with value: 0.49264705882352944.
# [I 2025-12-07 07:12:12,494] Trial 3 finished with value: 0.4884488448844885 and parameters: {'t': 0.5428060509353626}. Best is trial 2 with value: 0.49264705882352944.
# [I 2025-12-07 07:12:12,499] Trial 4 finished with value: 0.2903225806451613 and parameters: {'t': 0.14885658999376852}. Best is trial 2 with value: 0.49264705882352944.
# [I 2025-12-07 07:12:12,504] Trial 5 finished with value: 0.2903225806451613 and parameters: {'t': 0.14883512309922037}. Best is trial 2 with value: 0.49264705882352944.
# [I 2025-12-07 07:12:12,510] Trial 6 finished with value: 0.07630116220313289 and parameters: {'t': 0.06169441482969752}. Best is trial 2 with value: 0.49264705882352944.
# [I 2025-12-07 07:12:12,514] Trial 7 finished with value: 0.4155844155844156 and parameters: {'t': 0.7808967697396924}. Best is trial 2 with value: 0.49264705882352944.
# [I 2025-12-07 07:12:12,519] Trial 8 finished with value: 0.4884488448844885 and parameters: {'t': 0.5449923604514558}. Best is trial 2 with value: 0.49264705882352944.
# [I 2025-12-07 07:12:12,523] Trial 9 finished with value: 0.4946236559139785 and parameters: {'t': 0.6401845942384805}. Best is trial 9 with value: 0.4946236559139785.
# [I 2025-12-07 07:12:12,529] Trial 10 finished with value: 0.4421052631578947 and parameters: {'t': 0.28709734798494785}. Best is trial 9 with value: 0.4946236559139785.
# [I 2025-12-07 07:12:12,535] Trial 11 finished with value: 0.4714828897338403 and parameters: {'t': 0.6891516983356998}. Best is trial 9 with value: 0.4946236559139785.
# [I 2025-12-07 07:12:12,541] Trial 12 finished with value: 0.5 and parameters: {'t': 0.6295448449889056}. Best is trial 12 with value: 0.5.
# [I 2025-12-07 07:12:12,546] Trial 13 finished with value: 0.4837758112094395 and parameters: {'t': 0.4658980749166799}. Best is trial 12 with value: 0.5.
# [I 2025-12-07 07:12:12,554] Trial 14 finished with value: 0.4794007490636704 and parameters: {'t': 0.6711440463288574}. Best is trial 12 with value: 0.5.
# [I 2025-12-07 07:12:12,562] Trial 15 finished with value: 0.4931506849315068 and parameters: {'t': 0.5897163515651863}. Best is trial 12 with value: 0.5.
# [I 2025-12-07 07:12:12,570] Trial 16 finished with value: 0.49066666666666664 and parameters: {'t': 0.3991980282850679}. Best is trial 12 with value: 0.5.
# [I 2025-12-07 07:12:12,575] Trial 17 finished with value: 0.4155844155844156 and parameters: {'t': 0.7800361365962762}. Best is trial 12 with value: 0.5.
# [I 2025-12-07 07:12:12,581] Trial 18 finished with value: 0.3671497584541063 and parameters: {'t': 0.856728710152719}. Best is trial 12 with value: 0.5.
# [I 2025-12-07 07:12:12,587] Trial 19 finished with value: 0.4924924924924925 and parameters: {'t': 0.4786669293010844}. Best is trial 12 with value: 0.5.
# [I 2025-12-07 07:12:12,593] Trial 20 finished with value: 0.4344262295081967 and parameters: {'t': 0.7492995414003145}. Best is trial 12 with value: 0.5.
# [I 2025-12-07 07:12:12,599] Trial 21 finished with value: 0.4965986394557823 and parameters: {'t': 0.5783009584816577}. Best is trial 12 with value: 0.5.
# [I 2025-12-07 07:12:12,605] Trial 22 finished with value: 0.49469964664310956 and parameters: {'t': 0.6176576095917179}. Best is trial 12 with value: 0.5.
# [I 2025-12-07 07:12:12,613] Trial 23 finished with value: 0.49498327759197325 and parameters: {'t': 0.5698970701223265}. Best is trial 12 with value: 0.5.
# [I 2025-12-07 07:12:12,619] Trial 24 finished with value: 0.48562300319488816 and parameters: {'t': 0.5205938632536131}. Best is trial 12 with value: 0.5.
# [I 2025-12-07 07:12:12,624] Trial 25 finished with value: 0.5013054830287206 and parameters: {'t': 0.39144026241746244}. Best is trial 25 with value: 0.5013054830287206.
# [I 2025-12-07 07:12:12,630] Trial 26 finished with value: 0.4919786096256685 and parameters: {'t': 0.40280601144888656}. Best is trial 25 with value: 0.5013054830287206.
# [I 2025-12-07 07:12:12,636] Trial 27 finished with value: 0.42045454545454547 and parameters: {'t': 0.25527607385215545}. Best is trial 25 with value: 0.5013054830287206.
# [I 2025-12-07 07:12:12,642] Trial 28 finished with value: 0.5025641025641026 and parameters: {'t': 0.3797250421630035}. Best is trial 28 with value: 0.5025641025641026.
# [I 2025-12-07 07:12:12,647] Trial 29 finished with value: 0.49019607843137253 and parameters: {'t': 0.35495884161692515}. Best is trial 28 with value: 0.5025641025641026.
# [I 2025-12-07 07:12:12,649] A new study created in memory with name: no-name-8c17b2dd-2251-49cf-a1bc-c78bc6965d3d
# [I 2025-12-07 07:12:12,653] Trial 0 finished with value: 0.36777583187390545 and parameters: {'t': 0.34334070577415265}. Best is trial 0 with value: 0.36777583187390545.
# [I 2025-12-07 07:12:12,658] Trial 1 finished with value: 0.26804123711340205 and parameters: {'t': 0.8561357327048255}. Best is trial 0 with value: 0.36777583187390545.
# [I 2025-12-07 07:12:12,662] Trial 2 finished with value: 0.41732283464566927 and parameters: {'t': 0.6614746082121505}. Best is trial 2 with value: 0.41732283464566927.
# [I 2025-12-07 07:12:12,668] Trial 3 finished with value: 0.4536082474226804 and parameters: {'t': 0.5428060509353626}. Best is trial 3 with value: 0.4536082474226804.
# [I 2025-12-07 07:12:12,673] Trial 4 finished with value: 0.23089983022071306 and parameters: {'t': 0.14885658999376852}. Best is trial 3 with value: 0.4536082474226804.
# [I 2025-12-07 07:12:12,677] Trial 5 finished with value: 0.23089983022071306 and parameters: {'t': 0.14883512309922037}. Best is trial 3 with value: 0.4536082474226804.
# [I 2025-12-07 07:12:12,681] Trial 6 finished with value: 0.08595327372368042 and parameters: {'t': 0.06169441482969752}. Best is trial 3 with value: 0.4536082474226804.
# [I 2025-12-07 07:12:12,684] Trial 7 finished with value: 0.36283185840707965 and parameters: {'t': 0.7808967697396924}. Best is trial 3 with value: 0.4536082474226804.
# [I 2025-12-07 07:12:12,688] Trial 8 finished with value: 0.4536082474226804 and parameters: {'t': 0.5449923604514558}. Best is trial 3 with value: 0.4536082474226804.
# [I 2025-12-07 07:12:12,691] Trial 9 finished with value: 0.416988416988417 and parameters: {'t': 0.6401845942384805}. Best is trial 3 with value: 0.4536082474226804.
# [I 2025-12-07 07:12:12,697] Trial 10 finished with value: 0.39316239316239315 and parameters: {'t': 0.3881167734237996}. Best is trial 3 with value: 0.4536082474226804.
# [I 2025-12-07 07:12:12,703] Trial 11 finished with value: 0.44518272425249167 and parameters: {'t': 0.526751660469508}. Best is trial 3 with value: 0.4536082474226804.
# [I 2025-12-07 07:12:12,710] Trial 12 finished with value: 0.4557823129251701 and parameters: {'t': 0.5356275852398906}. Best is trial 12 with value: 0.4557823129251701.
# [I 2025-12-07 07:12:12,720] Trial 13 finished with value: 0.34782608695652173 and parameters: {'t': 0.2996581554448274}. Best is trial 12 with value: 0.4557823129251701.
# [I 2025-12-07 07:12:12,727] Trial 14 finished with value: 0.41568627450980394 and parameters: {'t': 0.6593469424677143}. Best is trial 12 with value: 0.4557823129251701.
# [I 2025-12-07 07:12:12,733] Trial 15 finished with value: 0.4088397790055249 and parameters: {'t': 0.45717250232181506}. Best is trial 12 with value: 0.4557823129251701.
# [I 2025-12-07 07:12:12,738] Trial 16 finished with value: 0.4421052631578947 and parameters: {'t': 0.5525244355588598}. Best is trial 12 with value: 0.4557823129251701.
# [I 2025-12-07 07:12:12,745] Trial 17 finished with value: 0.36363636363636365 and parameters: {'t': 0.75152079247947}. Best is trial 12 with value: 0.4557823129251701.
# [I 2025-12-07 07:12:12,750] Trial 18 finished with value: 0.39598997493734334 and parameters: {'t': 0.43100554129972857}. Best is trial 12 with value: 0.4557823129251701.
# [I 2025-12-07 07:12:12,757] Trial 19 finished with value: 0.3338008415147265 and parameters: {'t': 0.2796916141105171}. Best is trial 12 with value: 0.4557823129251701.
# [I 2025-12-07 07:12:12,762] Trial 20 finished with value: 0.43343653250773995 and parameters: {'t': 0.48667288811989}. Best is trial 12 with value: 0.4557823129251701.
# [I 2025-12-07 07:12:12,767] Trial 21 finished with value: 0.43109540636042404 and parameters: {'t': 0.570914423220492}. Best is trial 12 with value: 0.4557823129251701.
# [I 2025-12-07 07:12:12,773] Trial 22 finished with value: 0.4264705882352941 and parameters: {'t': 0.594548464137596}. Best is trial 12 with value: 0.4557823129251701.
# [I 2025-12-07 07:12:12,780] Trial 23 finished with value: 0.358974358974359 and parameters: {'t': 0.7436220494956847}. Best is trial 12 with value: 0.4557823129251701.
# [I 2025-12-07 07:12:12,787] Trial 24 finished with value: 0.4394904458598726 and parameters: {'t': 0.49928939274536555}. Best is trial 12 with value: 0.4557823129251701.
# [I 2025-12-07 07:12:12,792] Trial 25 finished with value: 0.39036144578313253 and parameters: {'t': 0.4214125070358772}. Best is trial 12 with value: 0.4557823129251701.
# [I 2025-12-07 07:12:12,797] Trial 26 finished with value: 0.43018867924528303 and parameters: {'t': 0.6240024767812258}. Best is trial 12 with value: 0.4557823129251701.
# [I 2025-12-07 07:12:12,802] Trial 27 finished with value: 0.3884297520661157 and parameters: {'t': 0.6931871379537042}. Best is trial 12 with value: 0.4557823129251701.
# [I 2025-12-07 07:12:12,808] Trial 28 finished with value: 0.3904382470119522 and parameters: {'t': 0.3670242324963071}. Best is trial 12 with value: 0.4557823129251701.
# [I 2025-12-07 07:12:12,813] Trial 29 finished with value: 0.35467980295566504 and parameters: {'t': 0.3235562235672578}. Best is trial 12 with value: 0.4557823129251701.
# [I 2025-12-07 07:12:12,815] A new study created in memory with name: no-name-010ebc42-3e57-499b-a1f7-15d102a4ae96
# [I 2025-12-07 07:12:12,819] Trial 0 finished with value: 0.4721030042918455 and parameters: {'t': 0.34334070577415265}. Best is trial 0 with value: 0.4721030042918455.
# [I 2025-12-07 07:12:12,823] Trial 1 finished with value: 0.5021097046413502 and parameters: {'t': 0.8561357327048255}. Best is trial 1 with value: 0.5021097046413502.
# [I 2025-12-07 07:12:12,828] Trial 2 finished with value: 0.53125 and parameters: {'t': 0.6614746082121505}. Best is trial 2 with value: 0.53125.
# [I 2025-12-07 07:12:12,834] Trial 3 finished with value: 0.5267275097783573 and parameters: {'t': 0.5428060509353626}. Best is trial 2 with value: 0.53125.
# [I 2025-12-07 07:12:12,841] Trial 4 finished with value: 0.29919304779639977 and parameters: {'t': 0.14885658999376852}. Best is trial 2 with value: 0.53125.
# [I 2025-12-07 07:12:12,845] Trial 5 finished with value: 0.29919304779639977 and parameters: {'t': 0.14883512309922037}. Best is trial 2 with value: 0.53125.
# [I 2025-12-07 07:12:12,850] Trial 6 finished with value: 0.10546459706570274 and parameters: {'t': 0.06169441482969752}. Best is trial 2 with value: 0.53125.
# [I 2025-12-07 07:12:12,854] Trial 7 finished with value: 0.5175292153589316 and parameters: {'t': 0.7808967697396924}. Best is trial 2 with value: 0.53125.
# [I 2025-12-07 07:12:12,858] Trial 8 finished with value: 0.5274151436031331 and parameters: {'t': 0.5449923604514558}. Best is trial 2 with value: 0.53125.
# [I 2025-12-07 07:12:12,861] Trial 9 finished with value: 0.5318559556786704 and parameters: {'t': 0.6401845942384805}. Best is trial 9 with value: 0.5318559556786704.
# [I 2025-12-07 07:12:12,867] Trial 10 finished with value: 0.4505050505050505 and parameters: {'t': 0.28709734798494785}. Best is trial 9 with value: 0.5318559556786704.
# [I 2025-12-07 07:12:12,872] Trial 11 finished with value: 0.5366568914956011 and parameters: {'t': 0.6891516983356998}. Best is trial 11 with value: 0.5366568914956011.
# [I 2025-12-07 07:12:12,877] Trial 12 finished with value: 0.53077975376197 and parameters: {'t': 0.6295448449889056}. Best is trial 11 with value: 0.5366568914956011.
# [I 2025-12-07 07:12:12,882] Trial 13 finished with value: 0.5298621745788668 and parameters: {'t': 0.7236570201627119}. Best is trial 11 with value: 0.5366568914956011.
# [I 2025-12-07 07:12:12,887] Trial 14 finished with value: 0.49825378346915017 and parameters: {'t': 0.41661975167721427}. Best is trial 11 with value: 0.5366568914956011.
# [I 2025-12-07 07:12:12,897] Trial 15 finished with value: 0.5271317829457365 and parameters: {'t': 0.5344429331699219}. Best is trial 11 with value: 0.5366568914956011.
# [I 2025-12-07 07:12:12,903] Trial 16 finished with value: 0.44819277108433736 and parameters: {'t': 0.874389025650041}. Best is trial 11 with value: 0.5366568914956011.
# [I 2025-12-07 07:12:12,909] Trial 17 finished with value: 0.5285935085007728 and parameters: {'t': 0.7326399609826104}. Best is trial 11 with value: 0.5366568914956011.
# [I 2025-12-07 07:12:12,915] Trial 18 finished with value: 0.5345997286295794 and parameters: {'t': 0.6165461895098122}. Best is trial 11 with value: 0.5366568914956011.
# [I 2025-12-07 07:12:12,920] Trial 19 finished with value: 0.5128834355828221 and parameters: {'t': 0.47274752966248296}. Best is trial 11 with value: 0.5366568914956011.
# [I 2025-12-07 07:12:12,926] Trial 20 finished with value: 0.5168918918918919 and parameters: {'t': 0.788034989127446}. Best is trial 11 with value: 0.5366568914956011.
# [I 2025-12-07 07:12:12,931] Trial 21 finished with value: 0.53077975376197 and parameters: {'t': 0.6304687495226841}. Best is trial 11 with value: 0.5366568914956011.
# [I 2025-12-07 07:12:12,937] Trial 22 finished with value: 0.5341074020319303 and parameters: {'t': 0.6773262330301401}. Best is trial 11 with value: 0.5366568914956011.
# [I 2025-12-07 07:12:12,942] Trial 23 finished with value: 0.5347432024169184 and parameters: {'t': 0.7119662920244842}. Best is trial 11 with value: 0.5366568914956011.
# [I 2025-12-07 07:12:12,949] Trial 24 finished with value: 0.5270506108202443 and parameters: {'t': 0.8013021777367269}. Best is trial 11 with value: 0.5366568914956011.
# [I 2025-12-07 07:12:12,957] Trial 25 finished with value: 0.5296442687747036 and parameters: {'t': 0.5613852093889032}. Best is trial 11 with value: 0.5366568914956011.
# [I 2025-12-07 07:12:12,964] Trial 26 finished with value: 0.5298621745788668 and parameters: {'t': 0.7202300931917249}. Best is trial 11 with value: 0.5366568914956011.
# [I 2025-12-07 07:12:12,974] Trial 27 finished with value: 0.5090036014405762 and parameters: {'t': 0.4538433807978815}. Best is trial 11 with value: 0.5366568914956011.
# [I 2025-12-07 07:12:12,981] Trial 28 finished with value: 0.5342281879194631 and parameters: {'t': 0.5922163994477764}. Best is trial 11 with value: 0.5366568914956011.
# [I 2025-12-07 07:12:12,988] Trial 29 finished with value: 0.4786885245901639 and parameters: {'t': 0.35495884161692515}. Best is trial 11 with value: 0.5366568914956011.
# [I 2025-12-07 07:12:12,990] A new study created in memory with name: no-name-320cad68-d28f-4e26-a1c2-0f85687d4b7c
# [I 2025-12-07 07:12:12,996] Trial 0 finished with value: 0.4229390681003584 and parameters: {'t': 0.34334070577415265}. Best is trial 0 with value: 0.4229390681003584.
# [I 2025-12-07 07:12:13,000] Trial 1 finished with value: 0.5547445255474452 and parameters: {'t': 0.8561357327048255}. Best is trial 1 with value: 0.5547445255474452.
# [I 2025-12-07 07:12:13,006] Trial 2 finished with value: 0.5555555555555556 and parameters: {'t': 0.6614746082121505}. Best is trial 2 with value: 0.5555555555555556.
# [I 2025-12-07 07:12:13,014] Trial 3 finished with value: 0.5023255813953489 and parameters: {'t': 0.5428060509353626}. Best is trial 2 with value: 0.5555555555555556.
# [I 2025-12-07 07:12:13,020] Trial 4 finished with value: 0.16279069767441862 and parameters: {'t': 0.14885658999376852}. Best is trial 2 with value: 0.5555555555555556.
# [I 2025-12-07 07:12:13,025] Trial 5 finished with value: 0.16279069767441862 and parameters: {'t': 0.14883512309922037}. Best is trial 2 with value: 0.5555555555555556.
# [I 2025-12-07 07:12:13,030] Trial 6 finished with value: 0.03565640194489465 and parameters: {'t': 0.06169441482969752}. Best is trial 2 with value: 0.5555555555555556.
# [I 2025-12-07 07:12:13,035] Trial 7 finished with value: 0.5298013245033113 and parameters: {'t': 0.7808967697396924}. Best is trial 2 with value: 0.5555555555555556.
# [I 2025-12-07 07:12:13,041] Trial 8 finished with value: 0.5023255813953489 and parameters: {'t': 0.5449923604514558}. Best is trial 2 with value: 0.5555555555555556.
# [I 2025-12-07 07:12:13,046] Trial 9 finished with value: 0.5494505494505495 and parameters: {'t': 0.6401845942384805}. Best is trial 2 with value: 0.5555555555555556.
# [I 2025-12-07 07:12:13,054] Trial 10 finished with value: 0.35988200589970504 and parameters: {'t': 0.29547796661774295}. Best is trial 2 with value: 0.5555555555555556.
# [I 2025-12-07 07:12:13,063] Trial 11 finished with value: 0.5522388059701493 and parameters: {'t': 0.8633556870596201}. Best is trial 2 with value: 0.5555555555555556.
# [I 2025-12-07 07:12:13,074] Trial 12 finished with value: 0.5207100591715976 and parameters: {'t': 0.7364507020656168}. Best is trial 2 with value: 0.5555555555555556.
# [I 2025-12-07 07:12:13,082] Trial 13 finished with value: 0.53125 and parameters: {'t': 0.8754626919868788}. Best is trial 2 with value: 0.5555555555555556.
# [I 2025-12-07 07:12:13,091] Trial 14 finished with value: 0.550561797752809 and parameters: {'t': 0.6939809616080903}. Best is trial 2 with value: 0.5555555555555556.
# [I 2025-12-07 07:12:13,101] Trial 15 finished with value: 0.5145631067961165 and parameters: {'t': 0.5595037957141363}. Best is trial 2 with value: 0.5555555555555556.
# [I 2025-12-07 07:12:13,112] Trial 16 finished with value: 0.4609053497942387 and parameters: {'t': 0.4146467054773383}. Best is trial 2 with value: 0.5555555555555556.
# [I 2025-12-07 07:12:13,121] Trial 17 finished with value: 0.5405405405405406 and parameters: {'t': 0.7946700042117335}. Best is trial 2 with value: 0.5555555555555556.
# [I 2025-12-07 07:12:13,129] Trial 18 finished with value: 0.5555555555555556 and parameters: {'t': 0.6563846165664284}. Best is trial 2 with value: 0.5555555555555556.
# [I 2025-12-07 07:12:13,137] Trial 19 finished with value: 0.5513513513513514 and parameters: {'t': 0.6297870437044526}. Best is trial 2 with value: 0.5555555555555556.
# [I 2025-12-07 07:12:13,145] Trial 20 finished with value: 0.4634146341463415 and parameters: {'t': 0.4072321649636004}. Best is trial 2 with value: 0.5555555555555556.
# [I 2025-12-07 07:12:13,152] Trial 21 finished with value: 0.547486033519553 and parameters: {'t': 0.6682104298737475}. Best is trial 2 with value: 0.5555555555555556.
# [I 2025-12-07 07:12:13,162] Trial 22 finished with value: 0.5517241379310345 and parameters: {'t': 0.8102086963514104}. Best is trial 2 with value: 0.5555555555555556.
# [I 2025-12-07 07:12:13,168] Trial 23 finished with value: 0.4915254237288136 and parameters: {'t': 0.8960327923134926}. Best is trial 2 with value: 0.5555555555555556.
# [I 2025-12-07 07:12:13,174] Trial 24 finished with value: 0.5294117647058824 and parameters: {'t': 0.7330666559518069}. Best is trial 2 with value: 0.5555555555555556.
# [I 2025-12-07 07:12:13,181] Trial 25 finished with value: 0.5279187817258884 and parameters: {'t': 0.5852903978630954}. Best is trial 2 with value: 0.5555555555555556.
# [I 2025-12-07 07:12:13,188] Trial 26 finished with value: 0.5294117647058824 and parameters: {'t': 0.7342508030140834}. Best is trial 2 with value: 0.5555555555555556.
# [I 2025-12-07 07:12:13,195] Trial 27 finished with value: 0.47368421052631576 and parameters: {'t': 0.47710501339099076}. Best is trial 2 with value: 0.5555555555555556.
# [I 2025-12-07 07:12:13,202] Trial 28 finished with value: 0.47577092511013214 and parameters: {'t': 0.48529338185305115}. Best is trial 2 with value: 0.5555555555555556.
# [I 2025-12-07 07:12:13,210] Trial 29 finished with value: 0.3821656050955414 and parameters: {'t': 0.30903861444703695}. Best is trial 2 with value: 0.5555555555555556.
# [I 2025-12-07 07:12:13,212] A new study created in memory with name: no-name-46107ea1-8477-478d-8946-b8fcc560e221
# [I 2025-12-07 07:12:13,218] Trial 0 finished with value: 0.3137254901960784 and parameters: {'t': 0.34334070577415265}. Best is trial 0 with value: 0.3137254901960784.
# [I 2025-12-07 07:12:13,224] Trial 1 finished with value: 0.03592814371257485 and parameters: {'t': 0.8561357327048255}. Best is trial 0 with value: 0.3137254901960784.
# ...
# [I 2025-12-07 08:36:51,888] Trial 28 finished with value: 0.511326860841424 and parameters: {'t': 0.6953258265321289}. Best is trial 21 with value: 0.5211267605633803.
# [I 2025-12-07 08:36:51,895] Trial 29 finished with value: 0.5119047619047619 and parameters: {'t': 0.5848122322258847}. Best is trial 21 with value: 0.5211267605633803.
# [I 2025-12-07 08:36:51,897] A new study created in memory with name: no-name-0dc0f734-154f-4921-b1f6-d045f7a62f8e
# [I 2025-12-07 08:36:51,903] Trial 0 finished with value: 0.5164835164835165 and parameters: {'t': 0.34334070577415265}. Best is trial 0 with value: 0.5164835164835165.
# [I 2025-12-07 08:36:51,908] Trial 1 finished with value: 0.512396694214876 and parameters: {'t': 0.8561357327048255}. Best is trial 0 with value: 0.5164835164835165.
# [I 2025-12-07 08:36:51,912] Trial 2 finished with value: 0.5323741007194245 and parameters: {'t': 0.6614746082121505}. Best is trial 2 with value: 0.5323741007194245.
# [I 2025-12-07 08:36:51,916] Trial 3 finished with value: 0.528052805280528 and parameters: {'t': 0.5428060509353626}. Best is trial 2 with value: 0.5323741007194245.
# [I 2025-12-07 08:36:51,921] Trial 4 finished with value: 0.41312741312741313 and parameters: {'t': 0.14885658999376852}. Best is trial 2 with value: 0.5323741007194245.
# [I 2025-12-07 08:36:51,925] Trial 5 finished with value: 0.41312741312741313 and parameters: {'t': 0.14883512309922037}. Best is trial 2 with value: 0.5323741007194245.
# [I 2025-12-07 08:36:51,930] Trial 6 finished with value: 0.2318271119842829 and parameters: {'t': 0.06169441482969752}. Best is trial 2 with value: 0.5323741007194245.
# [I 2025-12-07 08:36:51,934] Trial 7 finished with value: 0.5234375 and parameters: {'t': 0.7808967697396924}. Best is trial 2 with value: 0.5323741007194245.
# [I 2025-12-07 08:36:51,939] Trial 8 finished with value: 0.528052805280528 and parameters: {'t': 0.5449923604514558}. Best is trial 2 with value: 0.5323741007194245.
# [I 2025-12-07 08:36:51,943] Trial 9 finished with value: 0.5338078291814946 and parameters: {'t': 0.6401845942384805}. Best is trial 9 with value: 0.5338078291814946.
# [I 2025-12-07 08:36:51,950] Trial 10 finished with value: 0.4961636828644501 and parameters: {'t': 0.28709734798494785}. Best is trial 9 with value: 0.5338078291814946.
# [I 2025-12-07 08:36:51,956] Trial 11 finished with value: 0.5362318840579711 and parameters: {'t': 0.6891516983356998}. Best is trial 11 with value: 0.5362318840579711.
# [I 2025-12-07 08:36:51,963] Trial 12 finished with value: 0.5352112676056338 and parameters: {'t': 0.6295448449889056}. Best is trial 11 with value: 0.5362318840579711.
# [I 2025-12-07 08:36:51,969] Trial 13 finished with value: 0.5151515151515151 and parameters: {'t': 0.7299159704101277}. Best is trial 11 with value: 0.5362318840579711.
# [I 2025-12-07 08:36:51,976] Trial 14 finished with value: 0.5370370370370371 and parameters: {'t': 0.4562834760584674}. Best is trial 14 with value: 0.5370370370370371.
# [I 2025-12-07 08:36:51,983] Trial 15 finished with value: 0.5144508670520231 and parameters: {'t': 0.38648977166763115}. Best is trial 14 with value: 0.5370370370370371.
# [I 2025-12-07 08:36:51,989] Trial 16 finished with value: 0.5316455696202531 and parameters: {'t': 0.48610811186554764}. Best is trial 14 with value: 0.5370370370370371.
# [I 2025-12-07 08:36:51,996] Trial 17 finished with value: 0.5104602510460251 and parameters: {'t': 0.8735120676726904}. Best is trial 14 with value: 0.5370370370370371.
# [I 2025-12-07 08:36:52,002] Trial 18 finished with value: 0.5317220543806647 and parameters: {'t': 0.42759691808952494}. Best is trial 14 with value: 0.5370370370370371.
# [I 2025-12-07 08:36:52,009] Trial 19 finished with value: 0.4973821989528796 and parameters: {'t': 0.3008072181348292}. Best is trial 14 with value: 0.5370370370370371.
# [I 2025-12-07 08:36:52,015] Trial 20 finished with value: 0.5210727969348659 and parameters: {'t': 0.7492995414003145}. Best is trial 14 with value: 0.5370370370370371.
# [I 2025-12-07 08:36:52,022] Trial 21 finished with value: 0.5333333333333333 and parameters: {'t': 0.6186197907061204}. Best is trial 14 with value: 0.5370370370370371.
# [I 2025-12-07 08:36:52,029] Trial 22 finished with value: 0.5249169435215947 and parameters: {'t': 0.5566097849247167}. Best is trial 14 with value: 0.5370370370370371.
# [I 2025-12-07 08:36:52,036] Trial 23 finished with value: 0.5408805031446541 and parameters: {'t': 0.47260044095640674}. Best is trial 23 with value: 0.5408805031446541.
# [I 2025-12-07 08:36:52,043] Trial 24 finished with value: 0.5349544072948328 and parameters: {'t': 0.4388877334003634}. Best is trial 23 with value: 0.5408805031446541.
# [I 2025-12-07 08:36:52,049] Trial 25 finished with value: 0.47754137115839246 and parameters: {'t': 0.2236592589934016}. Best is trial 23 with value: 0.5408805031446541.
# [I 2025-12-07 08:36:52,056] Trial 26 finished with value: 0.5316455696202531 and parameters: {'t': 0.4850519643136425}. Best is trial 23 with value: 0.5408805031446541.
# [I 2025-12-07 08:36:52,063] Trial 27 finished with value: 0.5381818181818182 and parameters: {'t': 0.6931871379537042}. Best is trial 23 with value: 0.5408805031446541.
# [I 2025-12-07 08:36:52,070] Trial 28 finished with value: 0.5129682997118156 and parameters: {'t': 0.3846374098353017}. Best is trial 23 with value: 0.5408805031446541.
# [I 2025-12-07 08:36:52,078] Trial 29 finished with value: 0.5182186234817814 and parameters: {'t': 0.8055819516755753}. Best is trial 23 with value: 0.5408805031446541.
# [I 2025-12-07 08:36:52,080] A new study created in memory with name: no-name-1284ddcd-feb3-4f99-90f3-668fe4c803ad
# [I 2025-12-07 08:36:52,084] Trial 0 finished with value: 0.6035426731078904 and parameters: {'t': 0.34334070577415265}. Best is trial 0 with value: 0.6035426731078904.
# [I 2025-12-07 08:36:52,088] Trial 1 finished with value: 0.11458885941644563 and parameters: {'t': 0.8561357327048255}. Best is trial 0 with value: 0.6035426731078904.
# [I 2025-12-07 08:36:52,093] Trial 2 finished with value: 0.33634719710669075 and parameters: {'t': 0.6614746082121505}. Best is trial 0 with value: 0.6035426731078904.
# [I 2025-12-07 08:36:52,099] Trial 3 finished with value: 0.4543987086359968 and parameters: {'t': 0.5428060509353626}. Best is trial 0 with value: 0.6035426731078904.
# [I 2025-12-07 08:36:52,105] Trial 4 finished with value: 0.6594933871329298 and parameters: {'t': 0.14885658999376852}. Best is trial 4 with value: 0.6594933871329298.
# [I 2025-12-07 08:36:52,110] Trial 5 finished with value: 0.659345584939489 and parameters: {'t': 0.14883512309922037}. Best is trial 4 with value: 0.6594933871329298.
# [I 2025-12-07 08:36:52,115] Trial 6 finished with value: 0.5721442885771543 and parameters: {'t': 0.06169441482969752}. Best is trial 4 with value: 0.6594933871329298.
# [I 2025-12-07 08:36:52,120] Trial 7 finished with value: 0.1974937343358396 and parameters: {'t': 0.7808967697396924}. Best is trial 4 with value: 0.6594933871329298.
# [I 2025-12-07 08:36:52,126] Trial 8 finished with value: 0.45145631067961167 and parameters: {'t': 0.5449923604514558}. Best is trial 4 with value: 0.6594933871329298.
# [I 2025-12-07 08:36:52,131] Trial 9 finished with value: 0.3543516873889876 and parameters: {'t': 0.6401845942384805}. Best is trial 4 with value: 0.6594933871329298.
# [I 2025-12-07 08:36:52,139] Trial 10 finished with value: 0.6368483412322274 and parameters: {'t': 0.28709734798494785}. Best is trial 4 with value: 0.6594933871329298.
# [I 2025-12-07 08:36:52,146] Trial 11 finished with value: 0.49151127191761756 and parameters: {'t': 0.012733412955084011}. Best is trial 4 with value: 0.6594933871329298.
# [I 2025-12-07 08:36:52,154] Trial 12 finished with value: 0.6648514851485149 and parameters: {'t': 0.19348548821925357}. Best is trial 12 with value: 0.6648514851485149.
# [I 2025-12-07 08:36:52,160] Trial 13 finished with value: 0.6590120160213618 and parameters: {'t': 0.2297024515142837}. Best is trial 12 with value: 0.6648514851485149.
# [I 2025-12-07 08:36:52,168] Trial 14 finished with value: 0.5854974704890388 and parameters: {'t': 0.3786614816851598}. Best is trial 12 with value: 0.6648514851485149.
# [I 2025-12-07 08:36:52,175] Trial 15 finished with value: 0.664796633941094 and parameters: {'t': 0.16555915259584633}. Best is trial 12 with value: 0.6648514851485149.
# [I 2025-12-07 08:36:52,181] Trial 16 finished with value: 0.6658773383850344 and parameters: {'t': 0.17214397924861266}. Best is trial 16 with value: 0.6658773383850344.
# [I 2025-12-07 08:36:52,188] Trial 17 finished with value: 0.5474740236474382 and parameters: {'t': 0.43422440017251474}. Best is trial 16 with value: 0.6658773383850344.
# [I 2025-12-07 08:36:52,195] Trial 18 finished with value: 0.6611183355006502 and parameters: {'t': 0.21522397110204133}. Best is trial 16 with value: 0.6658773383850344.
# [I 2025-12-07 08:36:52,202] Trial 19 finished with value: 0.6031575170434159 and parameters: {'t': 0.07858580943859521}. Best is trial 16 with value: 0.6658773383850344.
# [I 2025-12-07 08:36:52,209] Trial 20 finished with value: 0.6361233480176212 and parameters: {'t': 0.2814710197132278}. Best is trial 16 with value: 0.6658773383850344.
# [I 2025-12-07 08:36:52,215] Trial 21 finished with value: 0.6595551520653654 and parameters: {'t': 0.15340630534589844}. Best is trial 16 with value: 0.6658773383850344.
# [I 2025-12-07 08:36:52,220] Trial 22 finished with value: 0.660436137071651 and parameters: {'t': 0.2141922715195538}. Best is trial 16 with value: 0.6658773383850344.
# [I 2025-12-07 08:36:52,226] Trial 23 finished with value: 0.6159610340951668 and parameters: {'t': 0.09044761744724546}. Best is trial 16 with value: 0.6658773383850344.
# [I 2025-12-07 08:36:52,232] Trial 24 finished with value: 0.6166405023547881 and parameters: {'t': 0.32428647282062983}. Best is trial 16 with value: 0.6658773383850344.
# [I 2025-12-07 08:36:52,239] Trial 25 finished with value: 0.5537366548042705 and parameters: {'t': 0.4263808191584778}. Best is trial 16 with value: 0.6658773383850344.
# [I 2025-12-07 08:36:52,245] Trial 26 finished with value: 0.49460859823554126 and parameters: {'t': 0.0212965248793352}. Best is trial 16 with value: 0.6658773383850344.
# [I 2025-12-07 08:36:52,251] Trial 27 finished with value: 0.6596412556053811 and parameters: {'t': 0.14893718036068054}. Best is trial 16 with value: 0.6658773383850344.
# [I 2025-12-07 08:36:52,258] Trial 28 finished with value: 0.6550387596899225 and parameters: {'t': 0.24775790290604505}. Best is trial 16 with value: 0.6658773383850344.
# [I 2025-12-07 08:36:52,264] Trial 29 finished with value: 0.5975809087937234 and parameters: {'t': 0.35495884161692515}. Best is trial 16 with value: 0.6658773383850344.
# Val micro-F1: 0.5975 | Val macro-F1: 0.5469
# Top checkpoints: [(0.6039949713647157, 'ckpt_epoch02_micro0.6040.pt'), (0.6008994632235601, 'ckpt_epoch03_micro0.6009.pt'), (0.6003269599829412, 'ckpt_epoch01_micro0.6003.pt')]
#
# Training finished. Best val micro-F1: 0.6039949713647157
# Ensembling top checkpoints...
# Predict:   0%|          | 0/272 [00:00<?, ?it/s]
# Predict:   0%|          | 0/272 [00:00<?, ?it/s]
# Exception ignored in: Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7d3158b560c0><function _MultiProcessingDataLoaderIter.__del__ at 0x7d3158b560c0>
#
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 1654, in __del__
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 1654, in __del__
#         self._shutdown_workers()self._shutdown_workers()
#
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 1637, in _shutdown_workers
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 1637, in _shutdown_workers
#         if w.is_alive():if w.is_alive():
#
#               ^^^^^^^^Exception ignored in: Exception ignored in: ^^^<function _MultiProcessingDataLoaderIter.__del__ at 0x7d3158b560c0>^^^
# ^<function _MultiProcessingDataLoaderIter.__del__ at 0x7d3158b560c0>^Traceback (most recent call last):
# ^^
# ^  File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 1654, in __del__
# ^Traceback (most recent call last):
# ^^      File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 1654, in __del__
# ^^self._shutdown_workers()
#
#
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 160, in is_alive
# self._shutdown_workers()  File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 1637, in _shutdown_workers
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 160, in is_alive
#
#     assert self._parent_pid == os.getpid(), 'can only test a child process'      File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 1637, in _shutdown_workers
#
#     assert self._parent_pid == os.getpid(), 'can only test a child process'if w.is_alive(): if w.is_alive():
#
#
#                               ^  ^^^ ^^^^ ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# ^^  File "/usr/lib/python3.12/multiprocessing/process.py", line 160, in is_alive
# ^  File "/usr/lib/python3.12/multiprocessing/process.py", line 160, in is_alive
# ^^        ^^assert self._parent_pid == os.getpid(), 'can only test a child process'assert self._parent_pid == os.getpid(), 'can only test a child process'^^^
#
#  ^^  ^^  ^^ ^ ^  ^^ ^^  ^^  ^^ ^^  ^^  ^ ^^ ^^^^ ^^^^^^^^^^^^
# ^^AssertionError^^^^^
# : ^^AssertionError: can only test a child process^^can only test a child process
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^AssertionError
# : AssertionErrorcan only test a child process:
# can only test a child process
# Predict:   0%|          | 0/272 [00:00<?, ?it/s]
# Ensemble Test Micro-F1: 0.6046 | Macro-F1: 0.5284 | Weighted-F1: 0.6026
#
# Classification report (ensemble):
#                 precision    recall  f1-score   support
#
#     admiration       0.71      0.71      0.71       504
#      amusement       0.77      0.89      0.83       264
#          anger       0.52      0.44      0.48       198
#      annoyance       0.31      0.54      0.39       320
#       approval       0.38      0.47      0.42       351
#         caring       0.41      0.52      0.46       135
#      confusion       0.46      0.42      0.44       153
#      curiosity       0.45      0.76      0.56       284
#         desire       0.58      0.52      0.55        83
# disappointment       0.33      0.32      0.33       151
#    disapproval       0.43      0.47      0.45       267
#        disgust       0.56      0.46      0.51       123
#  embarrassment       0.61      0.38      0.47        37
#     excitement       0.36      0.52      0.42       103
#           fear       0.59      0.74      0.66        78
#      gratitude       0.96      0.88      0.91       352
#          grief       0.33      0.33      0.33         6
#            joy       0.57      0.65      0.61       161
#           love       0.76      0.82      0.79       238
#    nervousness       0.42      0.43      0.43        23
#       optimism       0.56      0.49      0.52       186
#          pride       0.50      0.38      0.43        16
#    realization       0.36      0.14      0.21       145
#         relief       0.44      0.36      0.40        11
#        remorse       0.52      0.89      0.65        56
#        sadness       0.71      0.49      0.58       156
#       surprise       0.62      0.52      0.57       141
#        neutral       0.58      0.83      0.69      1787
#
#      micro avg       0.56      0.66      0.60      6329
#      macro avg       0.53      0.55      0.53      6329
#   weighted avg       0.57      0.66      0.60      6329
#    samples avg       0.59      0.69      0.61      6329
#
#
# Example predictions:
# I am thrilled to see you! -> [('excitement', 0.9335727691650391)]
# I hate this so much. -> [('anger', 0.7611467242240906), ('annoyance', 0.4097802937030792)]
# Thanks for your help. -> [('gratitude', 0.9925387501716614)]
